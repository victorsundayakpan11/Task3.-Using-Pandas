# %% [markdown]
# <a href="https://colab.research.google.com/github/victorsundayakpan11/Task3.-Using-Pandas/blob/main/Copy_of_Week_3_Task_TC3_227.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
importimport pandas as pd

df = pd.read_csv("/content/netflix_titles.csv")
display(df.head(10))
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
display(df.shape)
# Out:
# (8807, 12)

# %%
display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# None

# %% [markdown]
# # Task
# Clean the data in the dataframe `data` loaded from "/content/netflix_titles.csv".

# %% [markdown]
# ## Identify and quantify missing values
#
# ### Subtask:
# Determine the exact number and percentage of missing values in each column.

# %% [markdown]
# **Reasoning**:
# Calculate and display the number and percentage of missing values for each column in the dataframe.

# %%
missing_values = df.isnull().sum()

missing_percentage = (missing_values / len(df)) * 10000
100

missing_info = pd.DataFrame({'Missing Count': missing_values, 'Missing Percentage (%)': missing_percentage})

display(missing_info)
# Out:
#               Missing Count  Missing Percentage (%)
# show_id                   0                0.000000
# type                      0                0.000000
# title                     0                0.000000
# director               2634             2990.802771
# cast                    825              936.754854
# country                 831              943.567617
# date_added               10               11.354604
# release_year              0                0.000000
# rating                    4                4.541842
# duration                  3                3.406381
# listed_in                 0                0.000000
# description               0                0.000000

# %%
missing_values = df.isnull().sum()
display(missing_values)
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ## Handle missing values
#
# ### Subtask:
# Based on the analysis of missing values, decide on the best strategy for each column (e.g., imputation, removal of rows/columns).

# %%
# Fill missing values in 'director', 'cast', and 'country' with 'Unknown'
df['direc'director''direc'director'tor'tor'] = df['director'].fillna('Unknown')
df['cast'] = df['cast'].fillna('Unknown')
df['country'] = df['country'].fillna('Unknown')

# Fill missing values in 'date_added', 'rating', and 'duration' with the mode
for col in ['date_added', 'rating', 'duration']:
    df[col] = df[col].fillna(df[col].mode()[0])

display(df.isnull().sum())
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %% [markdown]
# **Reasoning**:
# Based on the missing value analysis, 'director', 'cast', and 'country' have a high percentage of missing values and will be filled with 'Unknown'. 'date_added', 'rating', and 'duration' have a low percentage and will be filled with the mode.

# %%
dfdf['date_added'] = pd.to_datetime(df['date_added'], format='mixed')
display(df['date_added'].head())
display(df.info())
# Out:
# 0   2021-09-25
# 1   2021-09-24
# 2   2021-09-24
# 3   2021-09-24
# 4   2021-09-24
# Name: date_added, dtype: datetime64[ns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      8807 non-null   object
#  4   cast          8807 non-null   object
#  5   country       8807 non-null   object
#  6   date_added    8807 non-null   datetime64[ns]
#  7   release_year  8807 non-null   int64
#  8   rating        8807 non-null   object
#  9   duration      8807 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: datetime64[ns](1), int64(1), object(10)
# memory usage: 825.8+ KB
# None
